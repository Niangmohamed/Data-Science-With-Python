# %% [markdown]
# # Python: Pandas dataframes

# %% [markdown]
# **Goal**: select rows and values with indexes!

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Index-shared-by-all-columns" data-toc-modified-id="Index-shared-by-all-columns-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Index shared by all columns</a></span></li><li><span><a href="#Use-integer-indexes-to-select-rows" data-toc-modified-id="Use-integer-indexes-to-select-rows-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Use integer indexes to select rows</a></span></li><li><span><a href="#Use-custom-indexes" data-toc-modified-id="Use-custom-indexes-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Use custom indexes</a></span></li><li><span><a href="#Selecting-values-from-a-custom-index" data-toc-modified-id="Selecting-values-from-a-custom-index-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Selecting values from a custom index</a></span></li><li><span><a href="#Apply()-method-on-the-columns-of-a-dataframe" data-toc-modified-id="Apply()-method-on-the-columns-of-a-dataframe-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Apply() method on the columns of a dataframe</a></span></li><li><span><a href="#Apply()-method-on-the-rows-of-a-dataframe" data-toc-modified-id="Apply()-method-on-the-rows-of-a-dataframe-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Apply() method on the rows of a dataframe</a></span></li></ul></div>

# %% [markdown]
# ## Index shared by all columns

# %%
import pandas as pd

# %%
fandango = pd.read_csv("fandango_score_comparison.csv")
fandango.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
fandango.index
# Out:
# RangeIndex(start=0, stop=146, step=1)

# %%
fandango.shape
# Out:
# (146, 22)

# %% [markdown]
# ## Use integer indexes to select rows

# %%
fandango[0:5]
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
fandango[142:]
# Out:
#                                           FILM  RottenTomatoes  \
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
# 145                   63          68              6.4   6.7             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 142                   3.5     4.85          4.10  ...       3.60
# 143                   3.5     4.85          3.90  ...       3.70
# 144                   3.5     5.00          4.05  ...       3.90
# ...

# %%
fandango.loc[50]
# Out:
# FILM                          Pitch Perfect 2 (2015)
# RottenTomatoes                                    67
# RottenTomatoes_User                               68
# Metacritic                                        63
# Metacritic_User                                  5.7
# IMDB                                             6.7
# Fandango_Stars                                   4.5
# Fandango_Ratingvalue                             4.2
# RT_norm                                         3.35
# RT_user_norm                                     3.4
# Metacritic_norm                                 3.15
# Metacritic_user_nom                             2.85
# IMDB_norm                                       3.35
# RT_norm_round                                    3.5
# RT_user_norm_round                               3.5
# Metacritic_norm_round                            3.0
# Metacritic_user_norm_round                       3.0
# IMDB_norm_round                                  3.5
# ...

# %%
fandango.iloc[[45, 90]]
# Out:
#                                                FILM  RottenTomatoes  \
# 45                              Tomorrowland (2015)              50
# 90  The SpongeBob Movie: Sponge Out of Water (2015)              78
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 45                   53          60              6.4   6.6             4.0
# 90                   55          62              6.5   6.1             3.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 45                   3.7      2.5          2.65  ...       3.30
# 90                   3.3      3.9          2.75  ...       3.05
#
#     RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 45            2.5                 2.5                    3.0
# 90            4.0                 3.0                    3.0
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# ...

# %% [markdown]
# ## Use custom indexes

# %%
fandango_ind_film = fandango.set_index(keys="FILM", drop=False)
fandango_ind_film.head()
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
# Cinderella (2015)                            Cinderella (2015)
# Ant-Man (2015)                                  Ant-Man (2015)
# Do You Believe? (2015)                  Do You Believe? (2015)
# Hot Tub Time Machine 2 (2015)    Hot Tub Time Machine 2 (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
# Cinderella (2015)                           85                   80
# Ant-Man (2015)                              80                   90
# Do You Believe? (2015)                      18                   84
# Hot Tub Time Machine 2 (2015)               14                   28
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
# ...

# %%
fandango_ind_film.index
# Out:
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %% [markdown]
# ## Selecting values from a custom index

# %%
fandango_ind_film['Danny Collins (2015)':'Serena (2015)']
# Out:
#                                       FILM  RottenTomatoes  \
# FILM
# Danny Collins (2015)  Danny Collins (2015)              77
# Spare Parts (2015)      Spare Parts (2015)              52
# Serena (2015)                Serena (2015)              18
#
#                       RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# FILM
# Danny Collins (2015)                   75          58              7.1   7.1
# Spare Parts (2015)                     83          50              7.1   7.2
# Serena (2015)                          25          36              5.3   5.4
#
#                       Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Danny Collins (2015)             4.0                   4.0     3.85
# Spare Parts (2015)               4.5                   4.5     2.60
# Serena (2015)                    3.0                   3.0     0.90
#
#                       RT_user_norm  ...  IMDB_norm  RT_norm_round  \
# FILM                                ...
# ...

# %%
fandango_ind_film.loc['Danny Collins (2015)':'Serena (2015)']
# Out:
#                                       FILM  RottenTomatoes  \
# FILM
# Danny Collins (2015)  Danny Collins (2015)              77
# Spare Parts (2015)      Spare Parts (2015)              52
# Serena (2015)                Serena (2015)              18
#
#                       RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# FILM
# Danny Collins (2015)                   75          58              7.1   7.1
# Spare Parts (2015)                     83          50              7.1   7.2
# Serena (2015)                          25          36              5.3   5.4
#
#                       Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Danny Collins (2015)             4.0                   4.0     3.85
# Spare Parts (2015)               4.5                   4.5     2.60
# Serena (2015)                    3.0                   3.0     0.90
#
#                       RT_user_norm  ...  IMDB_norm  RT_norm_round  \
# FILM                                ...
# ...

# %%
movies = ["Danny Collins (2015)", "Spare Parts (2015)", "Serena (2015)"]
fandango_ind_film.loc[movies]
# Out:
#                                       FILM  RottenTomatoes  \
# FILM
# Danny Collins (2015)  Danny Collins (2015)              77
# Spare Parts (2015)      Spare Parts (2015)              52
# Serena (2015)                Serena (2015)              18
#
#                       RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# FILM
# Danny Collins (2015)                   75          58              7.1   7.1
# Spare Parts (2015)                     83          50              7.1   7.2
# Serena (2015)                          25          36              5.3   5.4
#
#                       Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Danny Collins (2015)             4.0                   4.0     3.85
# Spare Parts (2015)               4.5                   4.5     2.60
# Serena (2015)                    3.0                   3.0     0.90
#
#                       RT_user_norm  ...  IMDB_norm  RT_norm_round  \
# FILM                                ...
# ...

# %% [markdown]
# ## Apply() method on the columns of a dataframe

# %%
import numpy as np

# %%
types = fandango_ind_film.dtypes
types
# Out:
# FILM                           object
# RottenTomatoes                  int64
# RottenTomatoes_User             int64
# Metacritic                      int64
# Metacritic_User               float64
# IMDB                          float64
# Fandango_Stars                float64
# Fandango_Ratingvalue          float64
# RT_norm                       float64
# RT_user_norm                  float64
# Metacritic_norm               float64
# Metacritic_user_nom           float64
# IMDB_norm                     float64
# RT_norm_round                 float64
# RT_user_norm_round            float64
# Metacritic_norm_round         float64
# Metacritic_user_norm_round    float64
# IMDB_norm_round               float64
# Metacritic_user_vote_count      int64
# IMDB_user_vote_count            int64
# Fandango_votes                  int64
# Fandango_Difference           float64
# dtype: object

# %%
float_columns = types[types.values == 'float64'].index
float_columns
# Out:
# Index(['Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Fandango_Difference'],
#       dtype='object')

# %%
float_fandando_ind_film = fandango_ind_film[float_columns]
float_fandando_ind_film.head()
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)              7.1   7.8             5.0
# Cinderella (2015)                           7.5   7.1             5.0
# Ant-Man (2015)                              8.1   7.8             5.0
# Do You Believe? (2015)                      4.7   5.4             5.0
# Hot Tub Time Machine 2 (2015)               3.4   5.1             3.5
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                   4.5     3.70           4.3
# Cinderella (2015)                                4.5     4.25           4.0
# Ant-Man (2015)                                   4.5     4.00           4.5
# Do You Believe? (2015)                           4.5     0.90           4.2
# Hot Tub Time Machine 2 (2015)                    3.0     0.70           1.4
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# ...

# %%
std = float_fandando_ind_film.apply(lambda x: np.std(x))
std
# Out:
# Metacritic_User               1.505529
# IMDB                          0.955447
# Fandango_Stars                0.538532
# Fandango_Ratingvalue          0.501106
# RT_norm                       1.503265
# RT_user_norm                  0.997787
# Metacritic_norm               0.972522
# Metacritic_user_nom           0.752765
# IMDB_norm                     0.477723
# RT_norm_round                 1.509404
# RT_user_norm_round            1.003559
# Metacritic_norm_round         0.987561
# Metacritic_user_norm_round    0.785412
# IMDB_norm_round               0.501043
# Fandango_Difference           0.152141
# dtype: float64

# %%
by_two = float_fandando_ind_film.apply(lambda x: x/2)
by_two.head()
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             3.55  3.90            2.50
# Cinderella (2015)                          3.75  3.55            2.50
# Ant-Man (2015)                             4.05  3.90            2.50
# Do You Believe? (2015)                     2.35  2.70            2.50
# Hot Tub Time Machine 2 (2015)              1.70  2.55            1.75
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                  2.25    1.850          2.15
# Cinderella (2015)                               2.25    2.125          2.00
# Ant-Man (2015)                                  2.25    2.000          2.25
# Do You Believe? (2015)                          2.25    0.450          2.10
# Hot Tub Time Machine 2 (2015)                   1.50    0.350          0.70
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# ...

# %% [markdown]
# ## Apply() method on the rows of a dataframe

# %%
rt_mt_user = float_fandando_ind_film[['RT_user_norm', 'Metacritic_user_nom']] 
rt_mt_user
# Out:
#                                            RT_user_norm  Metacritic_user_nom
# FILM
# Avengers: Age of Ultron (2015)                     4.30                 3.55
# Cinderella (2015)                                  4.00                 3.75
# Ant-Man (2015)                                     4.50                 4.05
# Do You Believe? (2015)                             4.20                 2.35
# Hot Tub Time Machine 2 (2015)                      1.40                 1.70
# ...                                                 ...                  ...
# Mr. Holmes (2015)                                  3.90                 3.95
# '71 (2015)                                         4.10                 3.75
# Two Days, One Night (2014)                         3.90                 4.40
# Gett: The Trial of Viviane Amsalem (2015)          4.05                 3.65
# Kumiko, The Treasure Hunter (2015)                 3.15                 3.20
#
# [146 rows x 2 columns]

# %%
rt_mt_user.apply(lambda x: np.std(x), axis=1)
# Out:
# FILM
# Avengers: Age of Ultron (2015)               0.375
# Cinderella (2015)                            0.125
# Ant-Man (2015)                               0.225
# Do You Believe? (2015)                       0.925
# Hot Tub Time Machine 2 (2015)                0.150
#                                              ...
# Mr. Holmes (2015)                            0.025
# '71 (2015)                                   0.175
# Two Days, One Night (2014)                   0.250
# Gett: The Trial of Viviane Amsalem (2015)    0.200
# Kumiko, The Treasure Hunter (2015)           0.025
# Length: 146, dtype: float64

# %%
rt_mt_means = rt_mt_user.apply(lambda x: np.mean(x), axis=1)
rt_mt_means
# Out:
# FILM
# Avengers: Age of Ultron (2015)               3.925
# Cinderella (2015)                            3.875
# Ant-Man (2015)                               4.275
# Do You Believe? (2015)                       3.275
# Hot Tub Time Machine 2 (2015)                1.550
#                                              ...
# Mr. Holmes (2015)                            3.925
# '71 (2015)                                   3.925
# Two Days, One Night (2014)                   4.150
# Gett: The Trial of Viviane Amsalem (2015)    3.850
# Kumiko, The Treasure Hunter (2015)           3.175
# Length: 146, dtype: float64
